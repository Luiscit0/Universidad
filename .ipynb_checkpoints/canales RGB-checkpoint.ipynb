# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt


image_path = 'avengers.png'
image = cv2.imread(image_path)


blue_channel, green_channel, red_channel = cv2.split(image)


blue_image = cv2.merge((blue_channel, np.zeros_like(green_channel), np.zeros_like(red_channel)))
green_image = cv2.merge((np.zeros_like(blue_channel), green_channel, np.zeros_like(red_channel)))
red_image = cv2.merge((np.zeros_like(blue_channel), np.zeros_like(green_channel), red_channel))


plt.figure(figsize=(12, 8))

plt.subplot(2, 2, 1)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title('Imagen Original')

plt.subplot(2, 2, 2)
plt.imshow(red_image)
plt.title('Canal Azul')

plt.subplot(2, 2, 3)
plt.imshow(green_image)
plt.title('Canal Verde')

plt.subplot(2, 2, 4)
plt.imshow(blue_image)
plt.title('Canal Rojo')

plt.tight_layout()
plt.show()

# %%
plt.subplot(2, 2, 2)
plt.imshow(red_image)
plt.title('Canal Azul')
# Out:
# Text(0.5, 1.0, 'Canal Azul')

# %%
plt.subplot(2, 2, 3)
plt.imshow(green_image)
plt.title('Canal Verde')
# Out:
# Text(0.5, 1.0, 'Canal Verde')

# %%
plt.subplot(2, 2, 4)
plt.imshow(blue_image)
plt.title('Canal Rojo')
# Out:
# Text(0.5, 1.0, 'Canal Rojo')
