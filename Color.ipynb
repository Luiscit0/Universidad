# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

imagen = cv2.imread('avengers.png', cv2.IMREAD_COLOR)
imagenRGB = cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB)
cv2.imwrite('avengers.png', imagenRGB)
imgc=imagenRGB.copy()

# %%
imagen.shape
# Out:
# (465, 948, 3)

# %%
objetivo=imagenRGB[225:505,400:710]
objetivo.shape
# Out:
# (240, 310, 3)

# %%
black=np.where((imagenRGB[:,:,0])&(imagenRGB[:,:,1])&(imagenRGB[:,:,2]))
black
# Out:
# (array([  0,   0,   0, ..., 464, 464, 464], dtype=int64),
#  array([  0,   1,   2, ..., 944, 945, 947], dtype=int64))

# %%
imgc=[400:705,700:1010]objetivo
# Out:
#   Cell In[10], line 1
#     imgc=[400:705,700:1010]objetivo
#              ^
# SyntaxError: invalid syntax

# %%
plt.figure(figsize=(15, 4))

plt.subplot(1, 3, 1)
plt.title('Imagen Original')
plt.imshow(imagenRGB)
plt.axis('off')

plt.subplot(1, 3, 2)
plt.title('Imagen Recortada')
plt.imshow(objetivo)
plt.axis('off')

plt.subplot(1, 3, 3)
plt.title('Imagen Agregada')
plt.imshow(imgc)
plt.axis('off')


plt.tight_layout()
plt.show()
